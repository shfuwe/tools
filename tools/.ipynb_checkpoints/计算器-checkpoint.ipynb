# %%
import math

# %%
math.log(100, 10)
# Out:
# 2.0

# %%
def xn(n):
    if n==0:
        return 0
    return n*math.log(n, 2)

# %%
xn(4/6)+xn(2/6)
# Out:
# -0.9182958340544896

# %%
def cc(n):
    return -(xn(n)+xn(1-n))

# %%
cc(2/5)
# Out:
# 0.9709505944546686

# %%
cc(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3154/1319988574.py in <module>
# ----> 1 cc(1)
#
# /tmp/ipykernel_3154/2910011332.py in cc(n)
#       1 def cc(n):
# ----> 2     return -(xn(n)+xn(1-n))
#
# /tmp/ipykernel_3154/643635938.py in xn(n)
#       1 def xn(n):
# ----> 2     return n*math.log(n, 2)
#
# ValueError: math domain error
