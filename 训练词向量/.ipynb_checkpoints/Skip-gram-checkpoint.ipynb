# %%
import pandas as pd
path='/data/fuwen/bj/ctr/data/news_info.txt'
doc_info=pd.read_table(path,header=None)
doc_info
# Out:
#                 0                                    1             2     3  \
# 0       325279629                           合集|外交部每日答问  1.624890e+12   0.0
# 1       334493096                    汽车点评网友“毛蒙”分享的小视频“  1.563405e+12   0.0
# 2       341014580         抖音爆红车模小姐姐,可爱如神仙,如今大火的她还玩起这个!  1.567068e+12   3.0
# 3       344297472             一夜能挣30万的网红车模,她的捞金神器竟是这个!  1.569240e+12   3.0
# 4       347286095         男子购买假号牌被查,后备箱找到真车牌,车主直言不愿太高调  1.571271e+12   3.0
# ...           ...                                  ...           ...   ...
# 347461  464934262  发病率高达40%就诊率仅9.4%!女性羞于启齿的“社交癌”你了解多少?  1.625068e+12   3.0
# 347462  464934523         50分惨败!昔日非洲篮坛霸主彻底没落,曾是中国男篮老对手  1.625068e+12   6.0
# 347463  464934569                     马上到!宝鸡雷电预警……做好防护  1.625042e+12   4.0
# 347464  464934651       《好声音》史上最讽刺的3场比赛:赢家销声匿迹,淘汰者越来越火  1.625068e+12  16.0
# 347465  464934838                    贷款买房好还是全款买房好看完就明了  1.625068e+12   6.0
#
#           4               5                                                  6
# 0       NaN             NaN                                                NaN
# 1        汽车           汽车/其他                                     https:8.135272
# 2        娱乐           娱乐/其他  初恋:11.052198,吊坠:9.525825,吊坠^^耳环:7.982950,妆容:10...
# 3        娱乐           娱乐/其他  主播:10.299306,发展:7.355088,可爱:8.705284,清纯:10.108...
# 4        汽车           汽车/用车  买车:9.357286,交警:8.964902,交通:7.790495,交通^^秩序:10....
# ...     ...             ...                                                ...
# 347461   健康  健康/疾病防护治疗及西医用药  ics:8.456915,oab:10.391586,oab^^患者:7.256806,oa...
# 347462   体育         体育/中国篮球  三分球:8.266778,世界大赛:8.078333,世界杯:10.498599,世锦赛:1...
# 347463   天气         天气/天气预报  冰雹:10.477194,凤县:15.765309,凤翔:11.166350,千阳县:16....
# 347464   综艺         综艺/内地综艺  90后:7.156848,ain:9.383776,中国^^好^^声音:9.787591,代...
# 347465   房产         房产/买房卖房  二手房:9.346363,人生:6.270345,低收入:6.587542,利息:9.779...
#
# [347466 rows x 7 columns]

# %%
text=[doc_info.loc[i][1] for i in range(len(doc_info))]
text[0:3]
# Out:
# ['合集|外交部每日答问', '汽车点评网友“毛蒙”分享的小视频“', '抖音爆红车模小姐姐,可爱如神仙,如今大火的她还玩起这个!']

# %%
import jieba
def tokenize(text,stop):
    """
    带有语料清洗功能的分词函数
    """
#     text = re.sub("\{%.+?%\}", " ", text)           # 去除 {%xxx%} (地理定位, 微博话题等)
#     text = re.sub("@.+?( |$)", " ", text)           # 去除 @xxx (用户名)
#     text = re.sub("【.+?】", " ", text)              # 去除 【xx】 (里面的内容通常都不是用户自己写的)
#     icons = re.findall("\[.+?\]", text)             # 提取出所有表情图标
#     text = re.sub("\[.+?\]", "IconMark", text)      # 将文本中的图标替换为`IconMark`

    tokens = []
    s=''
    for k, w in enumerate(jieba.lcut(text)):
        w = w.strip()#移除字符串头尾指定的字符
        if w in stop:
            continue
        if w.encode('utf-8').isalnum() is True:
          # print(w,w.encode('utf-8').isalnum())
          continue
        tokens.append(w)
        s+=w
        s+=" "
    return tokens,s
stopwords = []
with open("stop_wb.txt", "r", encoding="utf8") as f:
    for w in f:
        stopwords.append(w.strip())
tokenize(text[0],stopwords)
# Out:
# (['合集', '外交部', '每日', '答问'], '合集 外交部 每日 答问 ')

# %%
text_clear=[]
for i in text:
    if isinstance(i, str):
        tokens,s=tokenize(i,stopwords)
        text_clear.append(tokens)

# %%
print(len(text_clear),text_clear[0:3])
# Out:
# 347465 [['合集', '外交部', '每日', '答问'], ['汽车', '点评', '网友', '毛蒙', '分享', '的', '小视频'], ['抖音', '爆红', '车模', '小姐姐', '可爱', '如', '神仙', '如今', '大火', '的', '她', '还', '玩', '起', '这个']]

# %%
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence
import multiprocessing
model = Word2Vec(text_clear, vector_size=128, window=5, min_count=3, workers=multiprocessing.cpu_count(), sg=0)
# sg: 如果是0， 则是CBOW模型，是1则是Skip-Gram模型，默认是0即CBOW模型
model.save('v128.model')

# %%
from gensim.models import Word2Vec
model0 = Word2Vec.load('v128.model')
print(model0.wv['外交部'])
# Out:
# [-0.69215924 -0.42481866  0.35946828  1.9541593   0.2415489  -0.73407096
#   0.22579803 -0.19068107  0.29114228 -0.10254692  0.69104207 -0.17413896
#   1.345865   -0.93974864  0.4318973   1.616043   -0.4839019  -1.4992557
#   0.20081116  1.1221623   0.2844442   0.10000516 -0.04205958 -1.7414758
#  -1.5439006   0.00329002 -0.3530109  -0.9857732   0.26310563 -1.3334165
#   0.17896113 -0.3406646   1.495164   -0.16826363  0.07969604  0.5558796
#   1.2884221   1.3680984   0.9112786  -0.1367098   0.99547505  0.46255064
#  -0.01483367  0.30639285  1.1685007   1.1727605  -0.0460601  -0.38611358
#   0.0086734   0.21516392  0.6925465   0.17846838 -0.99055016  0.60554403
#  -0.2317854   0.3294808   0.4284177  -0.58639127 -0.5694783   1.0142622
#  -0.6423892   0.18508087 -0.15815789 -1.8028735  -1.5129228   0.00927596
#   0.48022896 -0.47236136  0.19157253  0.5573375   0.15667272 -0.53881234
#  -0.68757814 -0.47826758  0.8255418  -0.51930285 -1.8622402   0.52230936
#  -1.5142413  -0.12584747 -0.84106284  0.06304972 -0.6124611   1.5788063
#   1.0611733   0.7018668   0.38811782  0.96153635 -0.6715942   0.07459143
#  -1.0460932  -0.92254806  0.5884992   0.66870034  0.32244343 -0.16640824
#  -2.1016426   0.7666549   0.00526973  0.59663653 -1.9411821  -0.7454397
#   0.8429632   0.08267681  0.33296096 -0.5247864   0.10182073 -0.27114996
#   0.50993496 -0.6412432  -0.13146429 -0.07201815  0.85394925  0.23526998
#  -0.20441642 -1.9192713   0.03951868  0.6084885   0.55723184  0.58338445
#  -0.7095807  -0.67233753  1.0195887   0.85998154 -0.52703905 -0.39383724
#  -0.8172204   0.507536  ]

# %%
def get_similar_words_str(w, model, topn = 10):
    result_words = get_similar_words_list(w, model)    
    return str(result_words)


def get_similar_words_list(w, model, topn = 10):
    result_words = []
    try:
        similary_words = model.wv.most_similar(w, topn=10)
        print(similary_words)
        for (word, similarity) in similary_words:
            result_words.append(word)
        print(result_words)
    except:
        print("There are some errors!" + w)

    return result_words

# %%
get_similar_words_list('可爱',model0)
# Out:
# [('迷人', 0.7865161895751953), ('温柔', 0.7715341448783875), ('甜', 0.7692040801048279), ('接地', 0.7652543187141418), ('浪漫', 0.7641196250915527), ('俏皮', 0.7615000605583191), ('看着', 0.7605945467948914), ('有趣', 0.7604215741157532), ('安静', 0.7513545155525208), ('乖巧', 0.7504373788833618)]
# ['迷人', '温柔', '甜', '接地', '浪漫', '俏皮', '看着', '有趣', '安静', '乖巧']
# ['迷人', '温柔', '甜', '接地', '浪漫', '俏皮', '看着', '有趣', '安静', '乖巧']
